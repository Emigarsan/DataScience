# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualización con Matplotlib: Histogramas y diagramas de caja

# %% [markdown]
# Vamos a ver de forma sencilla como hacer los gráficos que nos generaban las funciones que empleamos en las visualizaciones analiticas del sprint anteior. En concreto, veremos los histogramas y los boxplots:

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Tan sencillo como:

# %%
plt.hist(np.random.randn(1000))
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Values')
# Out:
# Text(0.5, 1.0, 'Histogram of Random Values')

# %% [markdown]
# La función ``hist()`` tiene muchas opciones para ajustar tanto el cálculo como la visualización; aquí tienes un ejemplo de un histograma más personalizado (en el que tocamos el número de columnas `bins`, la transparencia y el color):

# %%
plt.hist(np.random.randn(1000), bins = 50)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Values')
# Out:
# Text(0.5, 1.0, 'Histogram of Random Values')

# %% [markdown]
# La transparencia es particularmente interesante para comparar histogramas o mostrar dicha comparación (y aprovecho para enseñarte un truco para cuando tengas argumentos repetidos que poner en tus llamadas a función):

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(alpha=0.5, bins=50)
plt.hist(x1, **kwargs, color='blue', label='x1')
plt.hist(x2, **kwargs, color='red', label='x2')
plt.hist(x3, **kwargs, color='green', label='x3')
plt.legend()

# %% [markdown]
# Es también el momento de enseñarte a capturar los límites de esos bines:

# %%
fig = plt.figure()
ax = plt.axes()
limites = ax.hist(x1,alpha=0.5, bins=50)

# %% [markdown]
# Limites es una tupla en la que el primer valor son los conteos y el segundo los límites de las barras:

# %%
limites[0]
limites[1]
# Out:
# array([-2.9657687 , -2.85302738, -2.74028605, -2.62754472, -2.51480339,
#        -2.40206207, -2.28932074, -2.17657941, -2.06383809, -1.95109676,
#        -1.83835543, -1.72561411, -1.61287278, -1.50013145, -1.38739012,
#        -1.2746488 , -1.16190747, -1.04916614, -0.93642482, -0.82368349,
#        -0.71094216, -0.59820084, -0.48545951, -0.37271818, -0.25997686,
#        -0.14723553, -0.0344942 ,  0.07824713,  0.19098845,  0.30372978,
#         0.41647111,  0.52921243,  0.64195376,  0.75469509,  0.86743641,
#         0.98017774,  1.09291907,  1.2056604 ,  1.31840172,  1.43114305,
#         1.54388438,  1.6566257 ,  1.76936703,  1.88210836,  1.99484968,
#         2.10759101,  2.22033234,  2.33307366,  2.44581499,  2.55855632,
#         2.67129765])

# %% [markdown]
# ### Boxplots
#
# Los diagramas de caja eran esos diagramas en los que resumíamos las medidas de posición y añadíamos una posible formar de obtener valores anómalos, extremos o outliers. En forma de diagrama:

# %% [markdown]
# ```text
#      Q1-1.5IQR   Q1  mediana  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers/outlier
#                        IQR
#
# ```

# %% [markdown]
# Donde IQR es el rango intercuartilico (la diferencia entre el valor de Q3 o tercer cuartil o percentil-75 y el valor de Q1 o primer cuartil, o percentil-25)

# %% [markdown]
# En matplotlib:

# %%
plt.boxplot(x1,whis=1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2952358af90>,
#   <matplotlib.lines.Line2D at 0x2952358b0e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2952358b230>,
#   <matplotlib.lines.Line2D at 0x2952358b380>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2952358ae40>],
#  'medians': [<matplotlib.lines.Line2D at 0x2952358b4d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2952358b620>],
#  'means': []}

# %% [markdown]
# En el caso de matplotlib empleamos por defecto diagramas de caja verticales. Pero podemos cambiarlo:

# %%
plt.boxplot(x1,whis=1.5,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x295235f6510>,
#   <matplotlib.lines.Line2D at 0x295235f6660>],
#  'caps': [<matplotlib.lines.Line2D at 0x295235f67b0>,
#   <matplotlib.lines.Line2D at 0x295235f6900>],
#  'boxes': [<matplotlib.lines.Line2D at 0x295235f63c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x295235f6a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x295235f6ba0>],
#  'means': []}

# %% [markdown]
# Y podemos mostrar varios juntos:

# %%
plt.boxplot([x1,x2,x3],whis=1.5,vert=False,labels=['x1','x2','x3'])
# Out:
# C:\Users\Emilio\AppData\Local\Temp\ipykernel_4260\2795839289.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([x1,x2,x3],whis=1.5,vert=False,labels=['x1','x2','x3'])
# {'whiskers': [<matplotlib.lines.Line2D at 0x2952366da90>,
#   <matplotlib.lines.Line2D at 0x2952366dbe0>,
#   <matplotlib.lines.Line2D at 0x2952366e3c0>,
#   <matplotlib.lines.Line2D at 0x2952366e510>,
#   <matplotlib.lines.Line2D at 0x2952366ecf0>,
#   <matplotlib.lines.Line2D at 0x2952366ee40>],
#  'caps': [<matplotlib.lines.Line2D at 0x2952366dd30>,
#   <matplotlib.lines.Line2D at 0x2952366de80>,
#   <matplotlib.lines.Line2D at 0x2952366e660>,
#   <matplotlib.lines.Line2D at 0x2952366e7b0>,
#   <matplotlib.lines.Line2D at 0x2952366ef90>,
#   <matplotlib.lines.Line2D at 0x2952366f0e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2952366d940>,
#   <matplotlib.lines.Line2D at 0x2952366e270>,
#   <matplotlib.lines.Line2D at 0x2952366eba0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2952366dfd0>,
#   <matplotlib.lines.Line2D at 0x2952366e900>,
#   <matplotlib.lines.Line2D at 0x2952366f230>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2952366e120>,
#   <matplotlib.lines.Line2D at 0x2952366ea50>,
#   <matplotlib.lines.Line2D at 0x2952366f380>],
#  'means': []}
